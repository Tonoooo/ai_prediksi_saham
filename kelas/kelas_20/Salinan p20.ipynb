# %% [markdown]
# # Program pembuat model kelas 19 pake GoogleColab
#
# sumber : https://youtu.be/-bN-R1D1Pe4

# %%
import pandas as pd
from keras.models import Sequential
from keras.layers import Dense, Dropout, BatchNormalization, LSTM
from keras.callbacks import ModelCheckpoint

# %%
# menghubungkan drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# mengimport file python/modul python yang ada di drive
import sys
sys.path.insert(0,'/content/drive/MyDrive/iky/fungsi')
import datanya

# %%
timestep = 80

# ~~~~~ file yang berisi ticker jadikan sebuah list
with open('drive/MyDrive/iky/data/ticker_issi.txt') as file:
    tick = file.readlines()
    ticker = [line.rstrip() for line in tick]# ini adalah list yang berisi ticker

# %%
## hari pertama -> 28-04-2022
# ticker = ticker[:19] # 2 jam ++

## hari kedua -> 29-04-2022
# ticker = ticker[19:150] # 12 jam 2 menit # sepertinya batas waktu runtime sampai 12 jam
# ticker = ticker[150:228] # 2 jam ++ . GPU

## hari ketiga -> 30-04-2022
# ticker = ticker[228:315] # 2 jam ++. GPU
# ticker = ticker[315:376] # 3 jam ++
# ticker = ticker[315:375]
# ticker = ticker[375:410]
# ticker = ticker[410:] # 1 jam 39 menit. GPU

# %%
for tic in ticker:
    df = pd.read_csv(f'drive/MyDrive/iky/data/bsaham/{tic}.csv')
    x_train, y_train = datanya.data_latih12(df, timestep)
    model = Sequential()
    model.add(LSTM(units=80, return_sequences=True, input_shape=(x_train.shape[1], 1)))
    model.add(Dropout(0.2))
    model.add(LSTM(units=80, return_sequences=True))
    model.add(Dropout(0.2))
    model.add(LSTM(units=80))
    model.add(Dropout(0.2))
    model.add(Dense(units=40))
    model.add(Dropout(0.2))
    model.add(Dense(units=1))
    model.compile(loss='mean_squared_error', optimizer='adam')
    filepath = f"drive/MyDrive/iky/kelas_20/model/{tic}_model.h5"
    checkpoint = ModelCheckpoint(filepath, monitor='loss', verbose=0, save_best_only=True, mode='min')
    callbacks_list = [checkpoint]
    model.fit(x_train, y_train, epochs=2, batch_size=1, callbacks=callbacks_list)
# Out:
# Epoch 1/2
# 2173/2173 [==============================] - 92s 39ms/step - loss: 0.0073
# Epoch 2/2
# 2173/2173 [==============================] - 81s 37ms/step - loss: 0.0048
# Epoch 1/2
# 447/447 [==============================] - 21s 38ms/step - loss: 0.0125
# Epoch 2/2
# 447/447 [==============================] - 17s 38ms/step - loss: 0.0093
# Epoch 1/2
# 2329/2329 [==============================] - 92s 37ms/step - loss: 0.0067
# Epoch 2/2
# 2329/2329 [==============================] - 87s 38ms/step - loss: 0.0043
# Epoch 1/2
# 298/298 [==============================] - 16s 38ms/step - loss: 0.0238
# Epoch 2/2
# 298/298 [==============================] - 12s 39ms/step - loss: 0.0131
# Epoch 1/2
# 5277/5277 [==============================] - 203s 38ms/step - loss: 0.0037
# Epoch 2/2
# 5277/5277 [==============================] - 198s 38ms/step - loss: 0.0018
# Epoch 1/2
# 871/871 [==============================] - 38s 38ms/step - loss: 0.0018
# Epoch 2/2
# 871/871 [==============================] - 33s 38ms/step - loss: 8.6622e-04
# Epoch 1/2
# 3997/3997 [==============================] - 154s 37ms/step - loss: 0.0039
# Epoch 2/2
# 3997/3997 [==============================] - 149s 37ms/step - loss: 0.0027
# Epoch 1/2
# 3759/3759 [==============================] - 142s 37ms/step - loss: 0.0067
# Epoch 2/2
# 3759/3759 [==============================] - 136s 36ms/step - loss: 0.0040
# Epoch 1/2
# 461/461 [==============================] - 22s 37ms/step - loss: 0.0146
# Epoch 2/2
# 461/461 [==============================] - 17s 38ms/step - loss: 0.0065
# Epoch 1/2
# 194/194 [==============================] - 12s 37ms/step - loss: 0.0508
# Epoch 2/2
# 194/194 [==============================] - 7s 37ms/step - loss: 0.0200
# Epoch 1/2
# 3998/3998 [==============================] - 152s 37ms/step - loss: 0.0072
# Epoch 2/2
# 3998/3998 [==============================] - 147s 37ms/step - loss: 0.0045
# Epoch 1/2
# 5290/5290 [==============================] - 196s 36ms/step - loss: 0.0043
# Epoch 2/2
